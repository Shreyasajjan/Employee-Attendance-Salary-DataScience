# %% [markdown]
# # 01 — Data Collection
# Generate and inspect the simulated employee and attendance datasets.

# %%
from src.data_generator import main
main()

# %%
import pandas as pd
employees = pd.read_csv('../data/raw/employees.csv')
attendance = pd.read_csv('../data/raw/attendance.csv')
print(employees.shape)
print(attendance.shape)
employees.head()
