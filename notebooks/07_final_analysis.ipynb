# %% [markdown]
# # 07 — Final Analysis
# Summarize generated outputs and derive business insights from actual data.

# %%
import pandas as pd
p = pd.read_csv('../data/processed/payroll_processed.csv')
a = pd.read_csv('../data/processed/cleaned_attendance.csv')
print('Employees:', len(p))
print('Total net salary:', round(p['Net_Salary'].sum(),2))
print('Average attendance:', round(p['Attendance_Percentage'].mean(),2))
print('Total overtime:', round(p['Overtime_Hours'].sum(),2))
