# %% [markdown]
# # 02 — Data Cleaning
# Inspect missing values, duplicates, types, invalid values and outliers.

# %%
from src.data_cleaning import clean_data
employees, attendance, quality = clean_data()
print(quality)

# %%
attendance.describe(include='all').T
