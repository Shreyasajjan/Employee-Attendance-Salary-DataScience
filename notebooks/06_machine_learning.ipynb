# %% [markdown]
# # 06 — Machine Learning
# Train and compare salary regression and attendance-risk classification models.

# %%
from src.ml_model import train_salary_models, train_attendance_risk_model
salary_results, salary_best = train_salary_models()
risk_results, risk_best = train_attendance_risk_model()
print(salary_results)
print(salary_best)
print(risk_results)
print(risk_best)
